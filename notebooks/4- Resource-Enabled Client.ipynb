# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\phil\.virtualenvs\spotify-api-gnpvqoks\lib\site-packages (2.24.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\phil\.virtualenvs\spotify-api-gnpvqoks\lib\site-packages (from requests) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\phil\.virtualenvs\spotify-api-gnpvqoks\lib\site-packages (from requests) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\phil\.virtualenvs\spotify-api-gnpvqoks\lib\site-packages (from requests) (1.25.9)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\phil\.virtualenvs\spotify-api-gnpvqoks\lib\site-packages (from requests) (2.10)

# %%
import requests
import datetime
from urllib.parse import urlencode

# %%
import base64

# %%
client_id = 'CLIENT_ID'
client_secret = 'CLIENT_SECRET'

# %%
class SpotifyAPI(object):
    access_token = None
    access_token_expires = datetime.datetime.now()
    access_token_did_expire = True
    client_id = None
    client_secret = None
    token_url = "https://accounts.spotify.com/api/token"
    
    def __init__(self, client_id, client_secret, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.client_id = client_id
        self.client_secret = client_secret

    def get_client_credentials(self):
        """
        Returns a base64 encoded string
        """
        client_id = self.client_id
        client_secret = self.client_secret
        if client_secret == None or client_id == None:
            raise Exception("You must set client_id and client_secret")
        client_creds = f"{client_id}:{client_secret}"
        client_creds_b64 = base64.b64encode(client_creds.encode())
        return client_creds_b64.decode()
    
    def get_token_headers(self):
        client_creds_b64 = self.get_client_credentials()
        return {
            "Authorization": f"Basic {client_creds_b64}"
        }
    
    def get_token_data(self):
        return {
            "grant_type": "client_credentials"
        } 
    
    def perform_auth(self):
        token_url = self.token_url
        token_data = self.get_token_data()
        token_headers = self.get_token_headers()
        r = requests.post(token_url, data=token_data, headers=token_headers)
        if r.status_code not in range(200, 299):
            raise Exception("Could not authenticate client.")
            # return False
        data = r.json()
        now = datetime.datetime.now()
        access_token = data['access_token']
        expires_in = data['expires_in'] # seconds
        expires = now + datetime.timedelta(seconds=expires_in)
        self.access_token = access_token
        self.access_token_expires = expires
        self.access_token_did_expire = expires < now
        return True
    
    def get_access_token(self):
        token = self.access_token
        expires = self.access_token_expires
        now = datetime.datetime.now()
        if expires < now:
            self.perform_auth()
            return self.get_access_token()
        elif token == None:
            self.perform_auth()
            return self.get_access_token() 
        return token
    
    def get_resource_header(self):
        access_token = self.get_access_token()
        headers = {
            "Authorization": f"Bearer {access_token}"
        }
        return headers
        
        
    def get_resource(self, lookup_id, resource_type='albums', version='v1'):
        endpoint = f"https://api.spotify.com/{version}/{resource_type}/{lookup_id}"
        headers = self.get_resource_header()
        r = requests.get(endpoint, headers=headers)
        if r.status_code not in range(200, 299):
            return {}
        return r.json()
    
    def get_album(self, _id):
        return self.get_resource(_id, resource_type='albums')
    
    def get_artist(self, _id):
        return self.get_resource(_id, resource_type='artists')
    
    def search(self, query, search_type='artist' ): # type
        headers = self.get_resource_header()
        endpoint = "https://api.spotify.com/v1/search"
        data = urlencode({"q": query, "type": search_type.lower()})
        lookup_url = f"{endpoint}?{data}"
        r = requests.get(lookup_url, headers=headers)
        if r.status_code not in range(200, 299):  
            return {}
        return r.json()

# %%
spotify = SpotifyAPI(client_id, client_secret)

# %%
spotify.search('Purple Rain', search_type='track')
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Purple+Rain&type=track&offset=0&limit=20',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5a2EaR3hamoenG9rDuVn8j'},
#        'href': 'https://api.spotify.com/v1/artists/5a2EaR3hamoenG9rDuVn8j',
#        'id': '5a2EaR3hamoenG9rDuVn8j',
#        'name': 'Prince',
#        'type': 'artist',
#        'uri': 'spotify:artist:5a2EaR3hamoenG9rDuVn8j'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7nXJ5k4XgRj5OLg9m8V3zc'},
#      'href': 'https://api.spotify.com/v1/albums/7nXJ5k4XgRj5OLg9m8V3zc',
#      'id': '7nXJ5k4XgRj5OLg9m8V3zc',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d52bfb90ee8dfeda8378b99b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d52bfb90ee8dfeda8378b99b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d52bfb90ee8dfeda8378b99b',
#        'width': 64}],
#      'name': 'Purple Rain',
#      'release_date': '1984-06-25',
#      'release_date_precision': 'day',
#      'total_tracks': 9,
#      'type': 'album',
#      'uri': 'spotify:album:7nXJ5k4XgRj5OLg9m8V3zc'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5a2EaR3hamoenG9rDuVn8j'},
#       'href': 'https://api.spotify.com/v1/artists/5a2EaR3hamoenG9rDuVn8j',
#       'id': '5a2EaR3hamoenG9rDuVn8j',
#       'name': 'Prince',
#       'type': 'artist',
#       'uri': 'spotify:artist:5a2EaR3hamoenG9rDuVn8j'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 520786,
#     'explicit': False,
#     'external_ids': {'isrc': 'USWB10001880'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/54X78diSLoUDI3joC2bjMz'},
#     'href': 'https://api.spotify.com/v1/tracks/54X78diSLoUDI3joC2bjMz',
#     'id': '54X78diSLoUDI3joC2bjMz',
#     'is_local': False,
#     'name': 'Purple Rain',
#     'popularity': 75,
#     'preview_url': 'https://p.scdn.co/mp3-preview/2fe008411edea4f21355301daa8993663eaf46f8?cid=38c840c7b1394a1a864fbc6b40e96d0d',
#     'track_number': 9,
#     'type': 'track',
#     'uri': 'spotify:track:54X78diSLoUDI3joC2bjMz'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2sxmKe3CUrWnx7eoXMhOlW'},
#        'href': 'https://api.spotify.com/v1/artists/2sxmKe3CUrWnx7eoXMhOlW',
#        'id': '2sxmKe3CUrWnx7eoXMhOlW',
#        'name': 'Dwight Yoakam',
#        'type': 'artist',
#        'uri': 'spotify:artist:2sxmKe3CUrWnx7eoXMhOlW'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3TQX6fqahJ102KUTfEr9lR'},
#      'href': 'https://api.spotify.com/v1/albums/3TQX6fqahJ102KUTfEr9lR',
#      'id': '3TQX6fqahJ102KUTfEr9lR',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2732f925abdec13a75dc61fa6f5',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e022f925abdec13a75dc61fa6f5',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048512f925abdec13a75dc61fa6f5',
#        'width': 64}],
#      'name': "Swimmin' Pools, Movie Stars…",
#      'release_date': '2016-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:3TQX6fqahJ102KUTfEr9lR'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2sxmKe3CUrWnx7eoXMhOlW'},
#       'href': 'https://api.spotify.com/v1/artists/2sxmKe3CUrWnx7eoXMhOlW',
#       'id': '2sxmKe3CUrWnx7eoXMhOlW',
#       'name': 'Dwight Yoakam',
#       'type': 'artist',
#       'uri': 'spotify:artist:2sxmKe3CUrWnx7eoXMhOlW'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 282960,
#     'explicit': False,
#     'external_ids': {'isrc': 'USC4R1601461'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6eo04yKCNmMegAvdQPEhm8'},
#     'href': 'https://api.spotify.com/v1/tracks/6eo04yKCNmMegAvdQPEhm8',
#     'id': '6eo04yKCNmMegAvdQPEhm8',
#     'is_local': False,
#     'name': 'Purple Rain',
#     'popularity': 46,
#     'preview_url': None,
#     'track_number': 12,
#     'type': 'track',
#     'uri': 'spotify:track:6eo04yKCNmMegAvdQPEhm8'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2NzXD6nzWnU3CvjCz2qQ2n'},
#        'href': 'https://api.spotify.com/v1/artists/2NzXD6nzWnU3CvjCz2qQ2n',
#        'id': '2NzXD6nzWnU3CvjCz2qQ2n',
#        'name': 'Kellz',
#        'type': 'artist',
#        'uri': 'spotify:artist:2NzXD6nzWnU3CvjCz2qQ2n'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2khfaEuPJEvMejYUOgJj3f'},
#      'href': 'https://api.spotify.com/v1/albums/2khfaEuPJEvMejYUOgJj3f',
#      'id': '2khfaEuPJEvMejYUOgJj3f',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273731e33c261be543a30ad62d0',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02731e33c261be543a30ad62d0',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851731e33c261be543a30ad62d0',
#        'width': 64}],
#      'name': 'Purple Rain Drops',
#      'release_date': '2020-07-07',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:2khfaEuPJEvMejYUOgJj3f'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2NzXD6nzWnU3CvjCz2qQ2n'},
#       'href': 'https://api.spotify.com/v1/artists/2NzXD6nzWnU3CvjCz2qQ2n',
#       'id': '2NzXD6nzWnU3CvjCz2qQ2n',
#       'name': 'Kellz',
#       'type': 'artist',
#       'uri': 'spotify:artist:2NzXD6nzWnU3CvjCz2qQ2n'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 174152,
#     'explicit': True,
#     'external_ids': {'isrc': 'GBKPL2007945'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0Ijs6yWBGzkQA8rsJAmKvK'},
#     'href': 'https://api.spotify.com/v1/tracks/0Ijs6yWBGzkQA8rsJAmKvK',
#     'id': '0Ijs6yWBGzkQA8rsJAmKvK',
#     'is_local': False,
#     'name': 'Purple Rain Drops',
#     'popularity': 46,
#     'preview_url': 'https://p.scdn.co/mp3-preview/d4a1cfe6346ebb7e2211f12e9ba082970f384800?cid=38c840c7b1394a1a864fbc6b40e96d0d',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0Ijs6yWBGzkQA8rsJAmKvK'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5a2EaR3hamoenG9rDuVn8j'},
#        'href': 'https://api.spotify.com/v1/artists/5a2EaR3hamoenG9rDuVn8j',
#        'id': '5a2EaR3hamoenG9rDuVn8j',
#        'name': 'Prince',
#        'type': 'artist',
#        'uri': 'spotify:artist:5a2EaR3hamoenG9rDuVn8j'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/12DmuRtZNTx84ELHKD3VGL'},
#      'href': 'https://api.spotify.com/v1/albums/12DmuRtZNTx84ELHKD3VGL',
#      'id': '12DmuRtZNTx84ELHKD3VGL',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273e2829416e5011fb749cc3fde',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02e2829416e5011fb749cc3fde',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851e2829416e5011fb749cc3fde',
#        'width': 64}],
#      'name': 'Purple Rain (Deluxe Expanded Edition)',
#      'release_date': '2017-06-23',
#      'release_date_precision': 'day',
#      'total_tracks': 35,
#      'type': 'album',
#      'uri': 'spotify:album:12DmuRtZNTx84ELHKD3VGL'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5a2EaR3hamoenG9rDuVn8j'},
#       'href': 'https://api.spotify.com/v1/artists/5a2EaR3hamoenG9rDuVn8j',
#       'id': '5a2EaR3hamoenG9rDuVn8j',
#       'name': 'Prince',
#       'type': 'artist',
#       'uri': 'spotify:artist:5a2EaR3hamoenG9rDuVn8j'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 524653,
#     'explicit': False,
#     'external_ids': {'isrc': 'USWB11700470'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1vfvy1Of0iJLDjh5eMfVyI'},
#     'href': 'https://api.spotify.com/v1/tracks/1vfvy1Of0iJLDjh5eMfVyI',
#     'id': '1vfvy1Of0iJLDjh5eMfVyI',
#     'is_local': False,
#     'name': 'Purple Rain - 2015 Paisley Park Remaster',
#     'popularity': 44,
#     'preview_url': 'https://p.scdn.co/mp3-preview/e2238903e5eb055748a38f8ba6d2bc03bc4df4a3?cid=38c840c7b1394a1a864fbc6b40e96d0d',
#     'track_number': 9,
#     'type': 'track',
#     'uri': 'spotify:track:1vfvy1Of0iJLDjh5eMfVyI'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4duJIuAjkc0AmqHmpC3uOS'},
#        'href': 'https://api.spotify.com/v1/artists/4duJIuAjkc0AmqHmpC3uOS',
#        'id': '4duJIuAjkc0AmqHmpC3uOS',
#        'name': 'Cole Albrighton',
#        'type': 'artist',
#        'uri': 'spotify:artist:4duJIuAjkc0AmqHmpC3uOS'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4En6uciHs2kWggvN1dCcuW'},
#      'href': 'https://api.spotify.com/v1/albums/4En6uciHs2kWggvN1dCcuW',
#      'id': '4En6uciHs2kWggvN1dCcuW',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2730ddb549d1e7447c698a27e20',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e020ddb549d1e7447c698a27e20',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048510ddb549d1e7447c698a27e20',
#        'width': 64}],
#      'name': 'Reflections',
#      'release_date': '2019-08-28',
#      'release_date_precision': 'day',
#      'total_tracks': 5,
#      'type': 'album',
#      'uri': 'spotify:album:4En6uciHs2kWggvN1dCcuW'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4duJIuAjkc0AmqHmpC3uOS'},
#       'href': 'https://api.spotify.com/v1/artists/4duJIuAjkc0AmqHmpC3uOS',
#       'id': '4duJIuAjkc0AmqHmpC3uOS',
#       'name': 'Cole Albrighton',
#       'type': 'artist',
#       'uri': 'spotify:artist:4duJIuAjkc0AmqHmpC3uOS'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 173333,
#     'explicit': False,
#     'external_ids': {'isrc': 'QZGWW1957132'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7iNC2PZRXqhKR7aKLjLnO8'},
#     'href': 'https://api.spotify.com/v1/tracks/7iNC2PZRXqhKR7aKLjLnO8',
#     'id': '7iNC2PZRXqhKR7aKLjLnO8',
#     'is_local': False,
#     'name': 'Purple Rain',
#     'popularity': 42,
#     'preview_url': 'https://p.scdn.co/mp3-preview/57b1622bea1877f53e750379603e6537f7fa2921?cid=38c840c7b1394a1a864fbc6b40e96d0d',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:7iNC2PZRXqhKR7aKLjLnO8'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5a2EaR3hamoenG9rDuVn8j'},
#        'href': 'https://api.spotify.com/v1/artists/5a2EaR3hamoenG9rDuVn8j',
#        'id': '5a2EaR3hamoenG9rDuVn8j',
#        'name': 'Prince',
#        'type': 'artist',
#        'uri': 'spotify:artist:5a2EaR3hamoenG9rDuVn8j'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6gbmDvcU1JDPy1niL6YFJY'},
#      'href': 'https://api.spotify.com/v1/albums/6gbmDvcU1JDPy1niL6YFJY',
#      'id': '6gbmDvcU1JDPy1niL6YFJY',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273105086205323b81177c709d4',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02105086205323b81177c709d4',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851105086205323b81177c709d4',
#        'width': 64}],
#      'name': 'Piano & A Microphone 1983',
#      'release_date': '2018-09-14',
#      'release_date_precision': 'day',
#      'total_tracks': 9,
#      'type': 'album',
#      'uri': 'spotify:album:6gbmDvcU1JDPy1niL6YFJY'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5a2EaR3hamoenG9rDuVn8j'},
#       'href': 'https://api.spotify.com/v1/artists/5a2EaR3hamoenG9rDuVn8j',
#       'id': '5a2EaR3hamoenG9rDuVn8j',
#       'name': 'Prince',
#       'type': 'artist',
#       'uri': 'spotify:artist:5a2EaR3hamoenG9rDuVn8j'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 86600,
#     'explicit': False,
#     'external_ids': {'isrc': 'USRH11801725'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2RapublkNolV5Ewmr7XtUH'},
#     'href': 'https://api.spotify.com/v1/tracks/2RapublkNolV5Ewmr7XtUH',
#     'id': '2RapublkNolV5Ewmr7XtUH',
#     'is_local': False,
#     'name': 'Purple Rain - Piano & A Microphone 1983 Version',
#     'popularity': 44,
#     'preview_url': 'https://p.scdn.co/mp3-preview/4940f15ba9745a4f45cdf84b4734e000369be07c?cid=38c840c7b1394a1a864fbc6b40e96d0d',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:2RapublkNolV5Ewmr7XtUH'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0iOVhN3tnSvgDbcg25JoJb'},
#        'href': 'https://api.spotify.com/v1/artists/0iOVhN3tnSvgDbcg25JoJb',
#        'id': '0iOVhN3tnSvgDbcg25JoJb',
#        'name': 'Etta James',
#        'type': 'artist',
#        'uri': 'spotify:artist:0iOVhN3tnSvgDbcg25JoJb'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7EVdCFnjNzPlPBWI89YtGs'},
#      'href': 'https://api.spotify.com/v1/albums/7EVdCFnjNzPlPBWI89YtGs',
#      'id': '7EVdCFnjNzPlPBWI89YtGs',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2739ac75f51841c3d4b2e702c11',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e029ac75f51841c3d4b2e702c11',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048519ac75f51841c3d4b2e702c11',
#        'width': 64}],
#      'name': 'All The Way',
#      'release_date': '2006-05-14',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:7EVdCFnjNzPlPBWI89YtGs'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0iOVhN3tnSvgDbcg25JoJb'},
#       'href': 'https://api.spotify.com/v1/artists/0iOVhN3tnSvgDbcg25JoJb',
#       'id': '0iOVhN3tnSvgDbcg25JoJb',
#       'name': 'Etta James',
#       'type': 'artist',
#       'uri': 'spotify:artist:0iOVhN3tnSvgDbcg25JoJb'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 344880,
#     'explicit': False,
#     'external_ids': {'isrc': 'USV110500314'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6If8Jwm6YvRlg2RFSviUKW'},
#     'href': 'https://api.spotify.com/v1/tracks/6If8Jwm6YvRlg2RFSviUKW',
#     'id': '6If8Jwm6YvRlg2RFSviUKW',
#     'is_local': False,
#     'name': 'Purple Rain',
#     'popularity': 42,
#     'preview_url': 'https://p.scdn.co/mp3-preview/912e5ea7d2950632ea6f1eba01eb5e83a3362945?cid=38c840c7b1394a1a864fbc6b40e96d0d',
#     'track_number': 9,
#     'type': 'track',
#     'uri': 'spotify:track:6If8Jwm6YvRlg2RFSviUKW'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0kU9wwMLox8HPLDr7XJt5S'},
#        'href': 'https://api.spotify.com/v1/artists/0kU9wwMLox8HPLDr7XJt5S',
#        'id': '0kU9wwMLox8HPLDr7XJt5S',
#        'name': 'Rock Piano Covers',
#        'type': 'artist',
#        'uri': 'spotify:artist:0kU9wwMLox8HPLDr7XJt5S'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/4Qaz0mzbBKpga3bjyks3g6'},
#        'href': 'https://api.spotify.com/v1/artists/4Qaz0mzbBKpga3bjyks3g6',
#        'id': '4Qaz0mzbBKpga3bjyks3g6',
#        'name': 'Piano Rock Covers',
#        'type': 'artist',
#        'uri': 'spotify:artist:4Qaz0mzbBKpga3bjyks3g6'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/0lGAVrjm3xxnlEwxpTzSct'},
#        'href': 'https://api.spotify.com/v1/artists/0lGAVrjm3xxnlEwxpTzSct',
#        'id': '0lGAVrjm3xxnlEwxpTzSct',
#        'name': 'Pieter Anø',
#        'type': 'artist',
#        'uri': 'spotify:artist:0lGAVrjm3xxnlEwxpTzSct'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6E5xzhI6zvTjeFL6eWHkqc'},
#      'href': 'https://api.spotify.com/v1/albums/6E5xzhI6zvTjeFL6eWHkqc',
#      'id': '6E5xzhI6zvTjeFL6eWHkqc',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27347de5576fadc11e7f6b31b5c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0247de5576fadc11e7f6b31b5c',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485147de5576fadc11e7f6b31b5c',
#        'width': 64}],
#      'name': 'Rock Piano Cover Hits',
#      'release_date': '2018-07-27',
#      'release_date_precision': 'day',
#      'total_tracks': 6,
#      'type': 'album',
#      'uri': 'spotify:album:6E5xzhI6zvTjeFL6eWHkqc'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0lGAVrjm3xxnlEwxpTzSct'},
#       'href': 'https://api.spotify.com/v1/artists/0lGAVrjm3xxnlEwxpTzSct',
#       'id': '0lGAVrjm3xxnlEwxpTzSct',
#       'name': 'Pieter Anø',
#       'type': 'artist',
#       'uri': 'spotify:artist:0lGAVrjm3xxnlEwxpTzSct'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 232000,
#     'explicit': False,
#     'external_ids': {'isrc': 'UKG8V1801403'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/54tKdN4lv72G528C3dFarm'},
#     'href': 'https://api.spotify.com/v1/tracks/54tKdN4lv72G528C3dFarm',
#     'id': '54tKdN4lv72G528C3dFarm',
#     'is_local': False,
#     'name': 'Purple Rain',
#     'popularity': 41,
#     'preview_url': 'https://p.scdn.co/mp3-preview/1d69674eae66d1dcdc8bc10255cbe11e08769aaf?cid=38c840c7b1394a1a864fbc6b40e96d0d',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:54tKdN4lv72G528C3dFarm'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0giUOGLTAaVVbdr7aSwM0N'},
#        'href': 'https://api.spotify.com/v1/artists/0giUOGLTAaVVbdr7aSwM0N',
#        'id': '0giUOGLTAaVVbdr7aSwM0N',
#        'name': 'CRIMEAPPLE',
#        'type': 'artist',
#        'uri': 'spotify:artist:0giUOGLTAaVVbdr7aSwM0N'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/1uD648fAShu4AT1hO43EFf'},
#        'href': 'https://api.spotify.com/v1/artists/1uD648fAShu4AT1hO43EFf',
#        'id': '1uD648fAShu4AT1hO43EFf',
#        'name': 'DJ Skizz',
#        'type': 'artist',
#        'uri': 'spotify:artist:1uD648fAShu4AT1hO43EFf'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0qpBSuJJ378p3FdMEIS3Fs'},
#      'href': 'https://api.spotify.com/v1/albums/0qpBSuJJ378p3FdMEIS3Fs',
#      'id': '0qpBSuJJ378p3FdMEIS3Fs',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273f05f186c4428650f419af529',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02f05f186c4428650f419af529',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851f05f186c4428650f419af529',
#        'width': 64}],
#      'name': 'Wet Dirt',
#      'release_date': '2019-02-07',
#      'release_date_precision': 'day',
#      'total_tracks': 9,
#      'type': 'album',
#      'uri': 'spotify:album:0qpBSuJJ378p3FdMEIS3Fs'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0giUOGLTAaVVbdr7aSwM0N'},
#       'href': 'https://api.spotify.com/v1/artists/0giUOGLTAaVVbdr7aSwM0N',
#       'id': '0giUOGLTAaVVbdr7aSwM0N',
#       'name': 'CRIMEAPPLE',
#       'type': 'artist',
#       'uri': 'spotify:artist:0giUOGLTAaVVbdr7aSwM0N'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1uD648fAShu4AT1hO43EFf'},
#       'href': 'https://api.spotify.com/v1/artists/1uD648fAShu4AT1hO43EFf',
#       'id': '1uD648fAShu4AT1hO43EFf',
#       'name': 'DJ Skizz',
#       'type': 'artist',
#       'uri': 'spotify:artist:1uD648fAShu4AT1hO43EFf'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 193643,
#     'explicit': False,
#     'external_ids': {'isrc': 'US92U1801509'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7xWLdZ3bmXa2HD1JzYa8mU'},
#     'href': 'https://api.spotify.com/v1/tracks/7xWLdZ3bmXa2HD1JzYa8mU',
#     'id': '7xWLdZ3bmXa2HD1JzYa8mU',
#     'is_local': False,
#     'name': 'Purple Rain',
#     'popularity': 34,
#     'preview_url': 'https://p.scdn.co/mp3-preview/1c0ed3c1d7d506946087705a4f8fa1368da5dc82?cid=38c840c7b1394a1a864fbc6b40e96d0d',
#     'track_number': 7,
#     'type': 'track',
#     'uri': 'spotify:track:7xWLdZ3bmXa2HD1JzYa8mU'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5bHjVR4F2Tfq4Ha6x7K6wU'},
#        'href': 'https://api.spotify.com/v1/artists/5bHjVR4F2Tfq4Ha6x7K6wU',
#        'id': '5bHjVR4F2Tfq4Ha6x7K6wU',
#        'name': 'Rockabye Baby!',
#        'type': 'artist',
#        'uri': 'spotify:artist:5bHjVR4F2Tfq4Ha6x7K6wU'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5ed0DmnELSdZNukVQFDSyF'},
#      'href': 'https://api.spotify.com/v1/albums/5ed0DmnELSdZNukVQFDSyF',
#      'id': '5ed0DmnELSdZNukVQFDSyF',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27310871891cbcecc6cf37d472e',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0210871891cbcecc6cf37d472e',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485110871891cbcecc6cf37d472e',
#        'width': 64}],
#      'name': 'Lullaby Renditions of Prince',
#      'release_date': '2012-09-25',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:5ed0DmnELSdZNukVQFDSyF'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5bHjVR4F2Tfq4Ha6x7K6wU'},
#       'href': 'https://api.spotify.com/v1/artists/5bHjVR4F2Tfq4Ha6x7K6wU',
#       'id': '5bHjVR4F2Tfq4Ha6x7K6wU',
#       'name': 'Rockabye Baby!',
#       'type': 'artist',
#       'uri': 'spotify:artist:5bHjVR4F2Tfq4Ha6x7K6wU'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 184160,
#     'explicit': False,
#     'external_ids': {'isrc': 'USEWC1288201'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6kFMm1tPOmudhBCoUZRLXE'},
#     'href': 'https://api.spotify.com/v1/tracks/6kFMm1tPOmudhBCoUZRLXE',
#     'id': '6kFMm1tPOmudhBCoUZRLXE',
#     'is_local': False,
#     'name': 'Purple Rain',
#     'popularity': 33,
#     'preview_url': 'https://p.scdn.co/mp3-preview/7b3a3149856c0cd66604b3a89beb321f799db935?cid=38c840c7b1394a1a864fbc6b40e96d0d',
#     'track_number': 13,
#     'type': 'track',
#     'uri': 'spotify:track:6kFMm1tPOmudhBCoUZRLXE'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5ZG7r3Jg0Y1hGQRMQ8hdRs'},
#        'href': 'https://api.spotify.com/v1/artists/5ZG7r3Jg0Y1hGQRMQ8hdRs',
#        'id': '5ZG7r3Jg0Y1hGQRMQ8hdRs',
#        'name': 'Inter Arma',
#        'type': 'artist',
#        'uri': 'spotify:artist:5ZG7r3Jg0Y1hGQRMQ8hdRs'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4Wv1Nvmw1HIprqEoSX07cv'},
#      'href': 'https://api.spotify.com/v1/albums/4Wv1Nvmw1HIprqEoSX07cv',
#      'id': '4Wv1Nvmw1HIprqEoSX07cv',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2731959a0f058e77e1202b3f13c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e021959a0f058e77e1202b3f13c',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048511959a0f058e77e1202b3f13c',
#        'width': 64}],
#      'name': 'Garbers Days Revisited',
#      'release_date': '2020-07-10',
#      'release_date_precision': 'day',
#      'total_tracks': 8,
#      'type': 'album',
#      'uri': 'spotify:album:4Wv1Nvmw1HIprqEoSX07cv'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5ZG7r3Jg0Y1hGQRMQ8hdRs'},
#       'href': 'https://api.spotify.com/v1/artists/5ZG7r3Jg0Y1hGQRMQ8hdRs',
#       'id': '5ZG7r3Jg0Y1hGQRMQ8hdRs',
#       'name': 'Inter Arma',
#       'type': 'artist',
#       'uri': 'spotify:artist:5ZG7r3Jg0Y1hGQRMQ8hdRs'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 473000,
#     'explicit': False,
#     'external_ids': {'isrc': 'US2642044608'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0tzfH5AOmKZElt7Q6me7Gb'},
#     'href': 'https://api.spotify.com/v1/tracks/0tzfH5AOmKZElt7Q6me7Gb',
#     'id': '0tzfH5AOmKZElt7Q6me7Gb',
# ...
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7zQLfHcIOrRePNj3QMs7wi'},
#      'href': 'https://api.spotify.com/v1/albums/7zQLfHcIOrRePNj3QMs7wi',
#      'id': '7zQLfHcIOrRePNj3QMs7wi',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2730a7d60335c42f5a4aa2ab273',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e020a7d60335c42f5a4aa2ab273',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048510a7d60335c42f5a4aa2ab273',
#        'width': 64}],
#      'name': 'Tower Sessions (Live)',
#      'release_date': '2010-06-14',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:7zQLfHcIOrRePNj3QMs7wi'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7hueZY91Csxv57p4KnPVcU'},
#       'href': 'https://api.spotify.com/v1/artists/7hueZY91Csxv57p4KnPVcU',
#       'id': '7hueZY91Csxv57p4KnPVcU',
#       'name': 'Aynsley Lister',
#       'type': 'artist',
#       'uri': 'spotify:artist:7hueZY91Csxv57p4KnPVcU'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 583920,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBKLA1102503'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/78R3EdSN5PFy1JpCSAFC5U'},
#     'href': 'https://api.spotify.com/v1/tracks/78R3EdSN5PFy1JpCSAFC5U',
#     'id': '78R3EdSN5PFy1JpCSAFC5U',
#     'is_local': False,
#     'name': 'Purple Rain - Live',
#     'popularity': 40,
#     'preview_url': 'https://p.scdn.co/mp3-preview/f48f52b5d7e8343f6b7216c4f44a5b13c7330466?cid=38c840c7b1394a1a864fbc6b40e96d0d',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:78R3EdSN5PFy1JpCSAFC5U'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5a2EaR3hamoenG9rDuVn8j'},
#        'href': 'https://api.spotify.com/v1/artists/5a2EaR3hamoenG9rDuVn8j',
#        'id': '5a2EaR3hamoenG9rDuVn8j',
#        'name': 'Prince',
#        'type': 'artist',
#        'uri': 'spotify:artist:5a2EaR3hamoenG9rDuVn8j'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2wLAcpM7FxdoC1dOdXfSNp'},
#      'href': 'https://api.spotify.com/v1/albums/2wLAcpM7FxdoC1dOdXfSNp',
#      'id': '2wLAcpM7FxdoC1dOdXfSNp',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27300b7c7b2941155504cc2b826',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0200b7c7b2941155504cc2b826',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485100b7c7b2941155504cc2b826',
#        'width': 64}],
#      'name': 'Prince and the Revolution: Live',
#      'release_date': '2020-05-15',
#      'release_date_precision': 'day',
#      'total_tracks': 20,
#      'type': 'album',
#      'uri': 'spotify:album:2wLAcpM7FxdoC1dOdXfSNp'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5a2EaR3hamoenG9rDuVn8j'},
#       'href': 'https://api.spotify.com/v1/artists/5a2EaR3hamoenG9rDuVn8j',
#       'id': '5a2EaR3hamoenG9rDuVn8j',
#       'name': 'Prince',
#       'type': 'artist',
#       'uri': 'spotify:artist:5a2EaR3hamoenG9rDuVn8j'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 1165933,
#     'explicit': False,
#     'external_ids': {'isrc': 'USWB12001304'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3J0LLcopxKyDVsq4QB0bFJ'},
#     'href': 'https://api.spotify.com/v1/tracks/3J0LLcopxKyDVsq4QB0bFJ',
#     'id': '3J0LLcopxKyDVsq4QB0bFJ',
#     'is_local': False,
#     'name': 'Purple Rain - Live in Syracuse, NY, 3/30/85',
#     'popularity': 37,
#     'preview_url': 'https://p.scdn.co/mp3-preview/e01e79fddd94f0f43ebccbdc8fa03361e45ea7ad?cid=38c840c7b1394a1a864fbc6b40e96d0d',
#     'track_number': 20,
#     'type': 'track',
#     'uri': 'spotify:track:3J0LLcopxKyDVsq4QB0bFJ'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00gjzT71CPCPmvrFda1EmX'},
#        'href': 'https://api.spotify.com/v1/artists/00gjzT71CPCPmvrFda1EmX',
#        'id': '00gjzT71CPCPmvrFda1EmX',
#        'name': 'Alternate Universe',
#        'type': 'artist',
#        'uri': 'spotify:artist:00gjzT71CPCPmvrFda1EmX'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/098EAjbx8FxQK5sHCJTqKG'},
#      'href': 'https://api.spotify.com/v1/albums/098EAjbx8FxQK5sHCJTqKG',
#      'id': '098EAjbx8FxQK5sHCJTqKG',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273fbac0fe1d2ad3d4e0f45dda9',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02fbac0fe1d2ad3d4e0f45dda9',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851fbac0fe1d2ad3d4e0f45dda9',
#        'width': 64}],
#      'name': 'Sink or Swim',
#      'release_date': '2020-06-18',
#      'release_date_precision': 'day',
#      'total_tracks': 2,
#      'type': 'album',
#      'uri': 'spotify:album:098EAjbx8FxQK5sHCJTqKG'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00gjzT71CPCPmvrFda1EmX'},
#       'href': 'https://api.spotify.com/v1/artists/00gjzT71CPCPmvrFda1EmX',
#       'id': '00gjzT71CPCPmvrFda1EmX',
#       'name': 'Alternate Universe',
#       'type': 'artist',
#       'uri': 'spotify:artist:00gjzT71CPCPmvrFda1EmX'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 98671,
#     'explicit': False,
#     'external_ids': {'isrc': 'QZAMM1872914'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6QTcVC8nDJf1Q8O4ibyFpo'},
#     'href': 'https://api.spotify.com/v1/tracks/6QTcVC8nDJf1Q8O4ibyFpo',
#     'id': '6QTcVC8nDJf1Q8O4ibyFpo',
#     'is_local': False,
#     'name': 'Purple Rain Puddles',
#     'popularity': 28,
#     'preview_url': 'https://p.scdn.co/mp3-preview/ec4c146253682fd45d79c763c2d82156fdae146b?cid=38c840c7b1394a1a864fbc6b40e96d0d',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:6QTcVC8nDJf1Q8O4ibyFpo'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/13HZbf3RY5Lpnp6rcp6UiM'},
#      'href': 'https://api.spotify.com/v1/albums/13HZbf3RY5Lpnp6rcp6UiM',
#      'id': '13HZbf3RY5Lpnp6rcp6UiM',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273fcbdc2efa4d58277d11197d4',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02fcbdc2efa4d58277d11197d4',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851fcbdc2efa4d58277d11197d4',
#        'width': 64}],
#      'name': 'Calm Ibiza - Edition 2012 (Pure Ibiza Chillout)',
#      'release_date': '2012-06-08',
#      'release_date_precision': 'day',
#      'total_tracks': 16,
#      'type': 'album',
#      'uri': 'spotify:album:13HZbf3RY5Lpnp6rcp6UiM'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0tOrKkXIn3VYyVHFEPG6Xd'},
#       'href': 'https://api.spotify.com/v1/artists/0tOrKkXIn3VYyVHFEPG6Xd',
#       'id': '0tOrKkXIn3VYyVHFEPG6Xd',
#       'name': 'Galimatias',
#       'type': 'artist',
#       'uri': 'spotify:artist:0tOrKkXIn3VYyVHFEPG6Xd'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 325434,
#     'explicit': False,
#     'external_ids': {'isrc': 'DEAS81100517'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4cPT2CeI7sFZTXNOV2SB8V'},
#     'href': 'https://api.spotify.com/v1/tracks/4cPT2CeI7sFZTXNOV2SB8V',
#     'id': '4cPT2CeI7sFZTXNOV2SB8V',
#     'is_local': False,
#     'name': 'Purple Rain',
#     'popularity': 28,
#     'preview_url': 'https://p.scdn.co/mp3-preview/261168ea95b8fc6bdc5d6075ab2dd2c3e0ee7386?cid=38c840c7b1394a1a864fbc6b40e96d0d',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:4cPT2CeI7sFZTXNOV2SB8V'}],
#   'limit': 20,
#   'next': 'https://api.spotify.com/v1/search?query=Purple+Rain&type=track&offset=20&limit=20',
#   'offset': 0,
#   'previous': None,
#   'total': 3170}}

# %%
spotify.get_artist('5a2EaR3hamoenG9rDuVn8j')
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/5a2EaR3hamoenG9rDuVn8j'},
#  'followers': {'href': None, 'total': 4550081},
#  'genres': ['funk', 'funk rock', 'minneapolis sound', 'motown', 'synth funk'],
#  'href': 'https://api.spotify.com/v1/artists/5a2EaR3hamoenG9rDuVn8j',
#  'id': '5a2EaR3hamoenG9rDuVn8j',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/0040a9952a800042a6e85b2ea3c3b9cb6a077edf',
#    'width': 640},
#   {'height': 320,
#    'url': 'https://i.scdn.co/image/f2456e75cf2da672e24ed7023338abef8ccb9c82',
#    'width': 320},
#   {'height': 160,
#    'url': 'https://i.scdn.co/image/b3b7dae5e718beb4917b8674d8e6fe50b82803d4',
#    'width': 160}],
#  'name': 'Prince',
#  'popularity': 76,
#  'type': 'artist',
#  'uri': 'spotify:artist:5a2EaR3hamoenG9rDuVn8j'}
