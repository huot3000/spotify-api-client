# %%
from spotify_client import *

# %%
client_id = 'CLIENT_ID'
client_secret = 'CLIENT_SECRET'

# %%
spotify = SpotifyAPI(client_id, client_secret)

# %%
spotify.search(query='Danger Zone', search_type='track')
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Danger+Zone&type=track&offset=0&limit=20',
#   'items': [{'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Y3xIwWyq5wnNHPp5gPjOW'},
#        'href': 'https://api.spotify.com/v1/artists/3Y3xIwWyq5wnNHPp5gPjOW',
#        'id': '3Y3xIwWyq5wnNHPp5gPjOW',
#        'name': 'Kenny Loggins',
#        'type': 'artist',
#        'uri': 'spotify:artist:3Y3xIwWyq5wnNHPp5gPjOW'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3uN87hwClF0hult2cxMbAW'},
#      'href': 'https://api.spotify.com/v1/albums/3uN87hwClF0hult2cxMbAW',
#      'id': '3uN87hwClF0hult2cxMbAW',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27319db9ac54c80a898a179f0f1',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0219db9ac54c80a898a179f0f1',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485119db9ac54c80a898a179f0f1',
#        'width': 64}],
#      'name': 'Yesterday, Today, Tomorrow - The Greatest Hits Of Kenny Loggins',
#      'release_date': '1997-03-25',
#      'release_date_precision': 'day',
#      'total_tracks': 15,
#      'type': 'album',
#      'uri': 'spotify:album:3uN87hwClF0hult2cxMbAW'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Y3xIwWyq5wnNHPp5gPjOW'},
#       'href': 'https://api.spotify.com/v1/artists/3Y3xIwWyq5wnNHPp5gPjOW',
#       'id': '3Y3xIwWyq5wnNHPp5gPjOW',
#       'name': 'Kenny Loggins',
#       'type': 'artist',
#       'uri': 'spotify:artist:3Y3xIwWyq5wnNHPp5gPjOW'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 215133,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM18600108'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/34x6hEJgGAOQvmlMql5Ige'},
#     'href': 'https://api.spotify.com/v1/tracks/34x6hEJgGAOQvmlMql5Ige',
#     'id': '34x6hEJgGAOQvmlMql5Ige',
#     'is_local': False,
#     'name': 'Danger Zone - From "Top Gun" Original Soundtrack',
#     'popularity': 72,
#     'preview_url': 'https://p.scdn.co/mp3-preview/37f82469e33bd437dd5b313796a6f7230d4dbd01?cid=38c840c7b1394a1a864fbc6b40e96d0d',
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:34x6hEJgGAOQvmlMql5Ige'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2kfVqdz3lJshqH9GUHhtMr'},
#        'href': 'https://api.spotify.com/v1/artists/2kfVqdz3lJshqH9GUHhtMr',
#        'id': '2kfVqdz3lJshqH9GUHhtMr',
#        'name': 'Psychostick',
#        'type': 'artist',
#        'uri': 'spotify:artist:2kfVqdz3lJshqH9GUHhtMr'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1GIf6jw4y0wh8mdf9kclPK'},
#      'href': 'https://api.spotify.com/v1/albums/1GIf6jw4y0wh8mdf9kclPK',
#      'id': '1GIf6jw4y0wh8mdf9kclPK',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2738efd97fa8c93bccf7ff9aa1a',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e028efd97fa8c93bccf7ff9aa1a',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048518efd97fa8c93bccf7ff9aa1a',
#        'width': 64}],
#      'name': 'IV: Revenge of the Vengeance',
#      'release_date': '2014-11-04',
#      'release_date_precision': 'day',
#      'total_tracks': 18,
#      'type': 'album',
#      'uri': 'spotify:album:1GIf6jw4y0wh8mdf9kclPK'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2kfVqdz3lJshqH9GUHhtMr'},
#       'href': 'https://api.spotify.com/v1/artists/2kfVqdz3lJshqH9GUHhtMr',
#       'id': '2kfVqdz3lJshqH9GUHhtMr',
#       'name': 'Psychostick',
#       'type': 'artist',
#       'uri': 'spotify:artist:2kfVqdz3lJshqH9GUHhtMr'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 230000,
#     'explicit': False,
#     'external_ids': {'isrc': 'USB761402574'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2nLq4qdtLXZnVllYlQ0WJn'},
#     'href': 'https://api.spotify.com/v1/tracks/2nLq4qdtLXZnVllYlQ0WJn',
#     'id': '2nLq4qdtLXZnVllYlQ0WJn',
#     'is_local': False,
#     'name': 'Danger Zone',
#     'popularity': 43,
#     'preview_url': 'https://p.scdn.co/mp3-preview/5e87d27d0448bf2c8b0d5583957709be429e9c8c?cid=38c840c7b1394a1a864fbc6b40e96d0d',
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:2nLq4qdtLXZnVllYlQ0WJn'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/30fiiwr2EeZp1tAhzYCmyM'},
#        'href': 'https://api.spotify.com/v1/artists/30fiiwr2EeZp1tAhzYCmyM',
#        'id': '30fiiwr2EeZp1tAhzYCmyM',
#        'name': 'Big L',
#        'type': 'artist',
#        'uri': 'spotify:artist:30fiiwr2EeZp1tAhzYCmyM'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7xvBUHu5jJ7X0wdRHudLFD'},
#      'href': 'https://api.spotify.com/v1/albums/7xvBUHu5jJ7X0wdRHudLFD',
#      'id': '7xvBUHu5jJ7X0wdRHudLFD',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273f22da4550a4de3cefb5afc0b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02f22da4550a4de3cefb5afc0b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851f22da4550a4de3cefb5afc0b',
#        'width': 64}],
#      'name': 'Lifestylez Ov Da Poor & Dangerous',
#      'release_date': '1995-03-28',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:7xvBUHu5jJ7X0wdRHudLFD'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/30fiiwr2EeZp1tAhzYCmyM'},
#       'href': 'https://api.spotify.com/v1/artists/30fiiwr2EeZp1tAhzYCmyM',
#       'id': '30fiiwr2EeZp1tAhzYCmyM',
#       'name': 'Big L',
#       'type': 'artist',
#       'uri': 'spotify:artist:30fiiwr2EeZp1tAhzYCmyM'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 216600,
#     'explicit': True,
#     'external_ids': {'isrc': 'USSM10022974'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0kU9oWqYnPeqEca3x2auV9'},
#     'href': 'https://api.spotify.com/v1/tracks/0kU9oWqYnPeqEca3x2auV9',
#     'id': '0kU9oWqYnPeqEca3x2auV9',
#     'is_local': False,
#     'name': 'Danger Zone',
#     'popularity': 42,
#     'preview_url': 'https://p.scdn.co/mp3-preview/495847449bde33b99caf856246227baa9e168126?cid=38c840c7b1394a1a864fbc6b40e96d0d',
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:0kU9oWqYnPeqEca3x2auV9'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/320TrJub4arztwXRm7kqVO'},
#        'href': 'https://api.spotify.com/v1/artists/320TrJub4arztwXRm7kqVO',
#        'id': '320TrJub4arztwXRm7kqVO',
#        'name': 'Dr. John',
#        'type': 'artist',
#        'uri': 'spotify:artist:320TrJub4arztwXRm7kqVO'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/73i095FtGSlyCoudRYl6MD'},
#        'href': 'https://api.spotify.com/v1/artists/73i095FtGSlyCoudRYl6MD',
#        'id': '73i095FtGSlyCoudRYl6MD',
#        'name': 'Erja Lyytinen',
#        'type': 'artist',
#        'uri': 'spotify:artist:73i095FtGSlyCoudRYl6MD'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3rwyu5r0KYOOuKBkcDmEaW'},
#      'href': 'https://api.spotify.com/v1/albums/3rwyu5r0KYOOuKBkcDmEaW',
#      'id': '3rwyu5r0KYOOuKBkcDmEaW',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2733c45356c1afaf55918ede0a2',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e023c45356c1afaf55918ede0a2',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048513c45356c1afaf55918ede0a2',
#        'width': 64}],
#      'name': 'Danger Zone',
#      'release_date': '2020-06-26',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:3rwyu5r0KYOOuKBkcDmEaW'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/320TrJub4arztwXRm7kqVO'},
#       'href': 'https://api.spotify.com/v1/artists/320TrJub4arztwXRm7kqVO',
#       'id': '320TrJub4arztwXRm7kqVO',
#       'name': 'Dr. John',
#       'type': 'artist',
#       'uri': 'spotify:artist:320TrJub4arztwXRm7kqVO'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/73i095FtGSlyCoudRYl6MD'},
#       'href': 'https://api.spotify.com/v1/artists/73i095FtGSlyCoudRYl6MD',
#       'id': '73i095FtGSlyCoudRYl6MD',
#       'name': 'Erja Lyytinen',
#       'type': 'artist',
#       'uri': 'spotify:artist:73i095FtGSlyCoudRYl6MD'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 230833,
#     'explicit': False,
#     'external_ids': {'isrc': 'QM6XS2001637'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7IS5tNszAGeBhpYLf3H2kC'},
#     'href': 'https://api.spotify.com/v1/tracks/7IS5tNszAGeBhpYLf3H2kC',
#     'id': '7IS5tNszAGeBhpYLf3H2kC',
#     'is_local': False,
#     'name': 'Danger Zone',
#     'popularity': 40,
#     'preview_url': 'https://p.scdn.co/mp3-preview/52cb831e003a71e6f39d59bbceff573e2cd1a01d?cid=38c840c7b1394a1a864fbc6b40e96d0d',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:7IS5tNszAGeBhpYLf3H2kC'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2zmq7HA083bUUqagbwKzEf'},
#      'href': 'https://api.spotify.com/v1/albums/2zmq7HA083bUUqagbwKzEf',
#      'id': '2zmq7HA083bUUqagbwKzEf',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273bc114bcd8e533beec77df770',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02bc114bcd8e533beec77df770',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851bc114bcd8e533beec77df770',
#        'width': 64}],
#      'name': '17 Again (Music From The Motion Picture)',
#      'release_date': '2009-04-14',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:2zmq7HA083bUUqagbwKzEf'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Y3xIwWyq5wnNHPp5gPjOW'},
#       'href': 'https://api.spotify.com/v1/artists/3Y3xIwWyq5wnNHPp5gPjOW',
#       'id': '3Y3xIwWyq5wnNHPp5gPjOW',
#       'name': 'Kenny Loggins',
#       'type': 'artist',
#       'uri': 'spotify:artist:3Y3xIwWyq5wnNHPp5gPjOW'}],
#     'available_markets': ['US'],
#     'disc_number': 1,
#     'duration_ms': 216666,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM19904142'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1xEg4DqjDUpNNl9kOL75xg'},
#     'href': 'https://api.spotify.com/v1/tracks/1xEg4DqjDUpNNl9kOL75xg',
#     'id': '1xEg4DqjDUpNNl9kOL75xg',
#     'is_local': False,
#     'name': 'Danger Zone',
#     'popularity': 28,
#     'preview_url': 'https://p.scdn.co/mp3-preview/4f453f4ff7df32965fa592a16834fe30dc9ac51e?cid=38c840c7b1394a1a864fbc6b40e96d0d',
#     'track_number': 13,
#     'type': 'track',
#     'uri': 'spotify:track:1xEg4DqjDUpNNl9kOL75xg'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0vDwx0CU6ln0giCDLK6k8D'},
#        'href': 'https://api.spotify.com/v1/artists/0vDwx0CU6ln0giCDLK6k8D',
#        'id': '0vDwx0CU6ln0giCDLK6k8D',
#        'name': 'Cherlene',
#        'type': 'artist',
#        'uri': 'spotify:artist:0vDwx0CU6ln0giCDLK6k8D'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7hkMT8fVCXHIyPCc5SbjjB'},
#      'href': 'https://api.spotify.com/v1/albums/7hkMT8fVCXHIyPCc5SbjjB',
#      'id': '7hkMT8fVCXHIyPCc5SbjjB',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273f767d0a4b1b27fc733c672ef',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02f767d0a4b1b27fc733c672ef',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851f767d0a4b1b27fc733c672ef',
#        'width': 64}],
#      'name': 'Cherlene (Songs from the Series Archer)',
#      'release_date': '2014-03-03',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:7hkMT8fVCXHIyPCc5SbjjB'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0vDwx0CU6ln0giCDLK6k8D'},
#       'href': 'https://api.spotify.com/v1/artists/0vDwx0CU6ln0giCDLK6k8D',
#       'id': '0vDwx0CU6ln0giCDLK6k8D',
#       'name': 'Cherlene',
#       'type': 'artist',
#       'uri': 'spotify:artist:0vDwx0CU6ln0giCDLK6k8D'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3Y3xIwWyq5wnNHPp5gPjOW'},
#       'href': 'https://api.spotify.com/v1/artists/3Y3xIwWyq5wnNHPp5gPjOW',
#       'id': '3Y3xIwWyq5wnNHPp5gPjOW',
#       'name': 'Kenny Loggins',
#       'type': 'artist',
#       'uri': 'spotify:artist:3Y3xIwWyq5wnNHPp5gPjOW'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 223186,
#     'explicit': False,
#     'external_ids': {'isrc': 'USFM91400002'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7vLGA5esH3V5STRGXw83wP'},
#     'href': 'https://api.spotify.com/v1/tracks/7vLGA5esH3V5STRGXw83wP',
#     'id': '7vLGA5esH3V5STRGXw83wP',
#     'is_local': False,
#     'name': 'Danger Zone Featuring Kenny Loggins',
#     'popularity': 39,
#     'preview_url': 'https://p.scdn.co/mp3-preview/168296280e5fe02337398f225624dd77c0a8953e?cid=38c840c7b1394a1a864fbc6b40e96d0d',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:7vLGA5esH3V5STRGXw83wP'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2KaW48xlLnXC2v8tvyhWsa'},
#        'href': 'https://api.spotify.com/v1/artists/2KaW48xlLnXC2v8tvyhWsa',
#        'id': '2KaW48xlLnXC2v8tvyhWsa',
#        'name': 'Amaranthe',
#        'type': 'artist',
#        'uri': 'spotify:artist:2KaW48xlLnXC2v8tvyhWsa'}],
#      'available_markets': ['AD',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'EC',
#       'EE',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'KZ',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'RO',
#       'RS',
#       'RU',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0GCcO9StyRRAGumjCOTSpN'},
#      'href': 'https://api.spotify.com/v1/albums/0GCcO9StyRRAGumjCOTSpN',
#      'id': '0GCcO9StyRRAGumjCOTSpN',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2737e1fea351d3673f4f94f5c8c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e027e1fea351d3673f4f94f5c8c',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048517e1fea351d3673f4f94f5c8c',
#        'width': 64}],
#      'name': 'MASSIVE ADDICTIVE',
#      'release_date': '2014-10-17',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:0GCcO9StyRRAGumjCOTSpN'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2KaW48xlLnXC2v8tvyhWsa'},
#       'href': 'https://api.spotify.com/v1/artists/2KaW48xlLnXC2v8tvyhWsa',
#       'id': '2KaW48xlLnXC2v8tvyhWsa',
#       'name': 'Amaranthe',
#       'type': 'artist',
#       'uri': 'spotify:artist:2KaW48xlLnXC2v8tvyhWsa'}],
#     'available_markets': ['AD',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'KZ',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'RO',
#      'RS',
#      'RU',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 181573,
#     'explicit': False,
#     'external_ids': {'isrc': 'FIUM71400491'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7kkNY7oiD6O1LliNRVN45A'},
#     'href': 'https://api.spotify.com/v1/tracks/7kkNY7oiD6O1LliNRVN45A',
#     'id': '7kkNY7oiD6O1LliNRVN45A',
#     'is_local': False,
#     'name': 'Danger Zone',
#     'popularity': 38,
#     'preview_url': None,
#     'track_number': 9,
#     'type': 'track',
#     'uri': 'spotify:track:7kkNY7oiD6O1LliNRVN45A'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4yiQZ8tQPux8cPriYMWUFP'},
#        'href': 'https://api.spotify.com/v1/artists/4yiQZ8tQPux8cPriYMWUFP',
#        'id': '4yiQZ8tQPux8cPriYMWUFP',
#        'name': 'Gwen Stefani',
#        'type': 'artist',
#        'uri': 'spotify:artist:4yiQZ8tQPux8cPriYMWUFP'}],
#      'available_markets': ['AD',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'EC',
#       'EE',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JP',
#       'KZ',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'RO',
#       'RS',
#       'RU',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3Lqn8M0QxPLIPRJ4nUKTGN'},
#      'href': 'https://api.spotify.com/v1/albums/3Lqn8M0QxPLIPRJ4nUKTGN',
#      'id': '3Lqn8M0QxPLIPRJ4nUKTGN',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2737c7136a182372ccdffb3d3c4',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e027c7136a182372ccdffb3d3c4',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048517c7136a182372ccdffb3d3c4',
#        'width': 64}],
#      'name': 'Love Angel Music Baby (Deluxe Version)',
#      'release_date': '2004-11-23',
#      'release_date_precision': 'day',
#      'total_tracks': 20,
#      'type': 'album',
#      'uri': 'spotify:album:3Lqn8M0QxPLIPRJ4nUKTGN'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4yiQZ8tQPux8cPriYMWUFP'},
#       'href': 'https://api.spotify.com/v1/artists/4yiQZ8tQPux8cPriYMWUFP',
#       'id': '4yiQZ8tQPux8cPriYMWUFP',
#       'name': 'Gwen Stefani',
#       'type': 'artist',
#       'uri': 'spotify:artist:4yiQZ8tQPux8cPriYMWUFP'}],
#     'available_markets': ['AD',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JP',
#      'KZ',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'RO',
#      'RS',
#      'RU',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 216800,
#     'explicit': False,
#     'external_ids': {'isrc': 'USIR10400849'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0wGcnSwFNCv9RFIMhO4ao2'},
#     'href': 'https://api.spotify.com/v1/tracks/0wGcnSwFNCv9RFIMhO4ao2',
#     'id': '0wGcnSwFNCv9RFIMhO4ao2',
#     'is_local': False,
#     'name': 'Danger Zone',
#     'popularity': 30,
#     'preview_url': None,
#     'track_number': 11,
#     'type': 'track',
#     'uri': 'spotify:track:0wGcnSwFNCv9RFIMhO4ao2'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2rVDi66o7gdeUq1OHUzM0W'},
#        'href': 'https://api.spotify.com/v1/artists/2rVDi66o7gdeUq1OHUzM0W',
#        'id': '2rVDi66o7gdeUq1OHUzM0W',
#        'name': 'The Protomen',
#        'type': 'artist',
#        'uri': 'spotify:artist:2rVDi66o7gdeUq1OHUzM0W'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2alFG2VsPE8xiozFQz3A0i'},
#      'href': 'https://api.spotify.com/v1/albums/2alFG2VsPE8xiozFQz3A0i',
#      'id': '2alFG2VsPE8xiozFQz3A0i',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273491b4c374353dcd9f60701cd',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02491b4c374353dcd9f60701cd',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851491b4c374353dcd9f60701cd',
#        'width': 64}],
#      'name': 'The Cover Up (Original Motion Picture Soundtrack)',
#      'release_date': '2015-02-20',
#      'release_date_precision': 'day',
#      'total_tracks': 15,
#      'type': 'album',
#      'uri': 'spotify:album:2alFG2VsPE8xiozFQz3A0i'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2rVDi66o7gdeUq1OHUzM0W'},
#       'href': 'https://api.spotify.com/v1/artists/2rVDi66o7gdeUq1OHUzM0W',
#       'id': '2rVDi66o7gdeUq1OHUzM0W',
#       'name': 'The Protomen',
#       'type': 'artist',
#       'uri': 'spotify:artist:2rVDi66o7gdeUq1OHUzM0W'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 244253,
#     'explicit': False,
#     'external_ids': {'isrc': 'TCACD1546249'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0XhcbuMPBRRcaqRiHMrnKl'},
#     'href': 'https://api.spotify.com/v1/tracks/0XhcbuMPBRRcaqRiHMrnKl',
#     'id': '0XhcbuMPBRRcaqRiHMrnKl',
#     'is_local': False,
#     'name': 'Danger Zone',
#     'popularity': 31,
#     'preview_url': 'https://p.scdn.co/mp3-preview/00c45f77951adbca891f1fbe7c24a9d4d0011303?cid=38c840c7b1394a1a864fbc6b40e96d0d',
#     'track_number': 14,
#     'type': 'track',
#     'uri': 'spotify:track:0XhcbuMPBRRcaqRiHMrnKl'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5HTnM2pBGio6w5JhaUmb4o'},
#        'href': 'https://api.spotify.com/v1/artists/5HTnM2pBGio6w5JhaUmb4o',
#        'id': '5HTnM2pBGio6w5JhaUmb4o',
#        'name': 'NAME SIX',
#        'type': 'artist',
#        'uri': 'spotify:artist:5HTnM2pBGio6w5JhaUmb4o'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5ahM64GGnNqq6fpf7HAdfy'},
#      'href': 'https://api.spotify.com/v1/albums/5ahM64GGnNqq6fpf7HAdfy',
#      'id': '5ahM64GGnNqq6fpf7HAdfy',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27351805ba101fa3640766d6b94',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0251805ba101fa3640766d6b94',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485151805ba101fa3640766d6b94',
#        'width': 64}],
#      'name': 'Danger Zone',
#      'release_date': '2018-01-24',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:5ahM64GGnNqq6fpf7HAdfy'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5HTnM2pBGio6w5JhaUmb4o'},
#       'href': 'https://api.spotify.com/v1/artists/5HTnM2pBGio6w5JhaUmb4o',
#       'id': '5HTnM2pBGio6w5JhaUmb4o',
#       'name': 'NAME SIX',
#       'type': 'artist',
#       'uri': 'spotify:artist:5HTnM2pBGio6w5JhaUmb4o'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 167418,
#     'explicit': False,
#     'external_ids': {'isrc': 'QZ8251907717'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/37QPYUR4c1jBWt3qP0swIx'},
#     'href': 'https://api.spotify.com/v1/tracks/37QPYUR4c1jBWt3qP0swIx',
#     'id': '37QPYUR4c1jBWt3qP0swIx',
#     'is_local': False,
#     'name': 'Danger Zone',
#     'popularity': 27,
#     'preview_url': 'https://p.scdn.co/mp3-preview/a1dc936ed5e5daeda83eed19655fd312b60c055b?cid=38c840c7b1394a1a864fbc6b40e96d0d',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:37QPYUR4c1jBWt3qP0swIx'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1co4F2pPNH8JjTutZkmgSm'},
#        'href': 'https://api.spotify.com/v1/artists/1co4F2pPNH8JjTutZkmgSm',
#        'id': '1co4F2pPNH8JjTutZkmgSm',
#        'name': 'Ramones',
#        'type': 'artist',
#        'uri': 'spotify:artist:1co4F2pPNH8JjTutZkmgSm'}],
#      'available_markets': ['CA', 'JP', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4szj932hnsBBNAfKwXAIKD'},
#      'href': 'https://api.spotify.com/v1/albums/4szj932hnsBBNAfKwXAIKD',
#      'id': '4szj932hnsBBNAfKwXAIKD',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273b273e56214705cc3f292f44e',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02b273e56214705cc3f292f44e',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851b273e56214705cc3f292f44e',
#        'width': 64}],
#      'name': 'Too Tough to Die (Expanded 2005 Remaster)',
#      'release_date': '1984-10-01',
#      'release_date_precision': 'day',
#      'total_tracks': 25,
#      'type': 'album',
#      'uri': 'spotify:album:4szj932hnsBBNAfKwXAIKD'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1co4F2pPNH8JjTutZkmgSm'},
#       'href': 'https://api.spotify.com/v1/artists/1co4F2pPNH8JjTutZkmgSm',
#       'id': '1co4F2pPNH8JjTutZkmgSm',
#       'name': 'Ramones',
#       'type': 'artist',
#       'uri': 'spotify:artist:1co4F2pPNH8JjTutZkmgSm'}],
#     'available_markets': ['CA', 'JP', 'US'],
#     'disc_number': 1,
#     'duration_ms': 128400,
#     'explicit': False,
#     'external_ids': {'isrc': 'USWB10201762'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4ftS7lkyqKQ3KtVdCnmINL'},
#     'href': 'https://api.spotify.com/v1/tracks/4ftS7lkyqKQ3KtVdCnmINL',
#     'id': '4ftS7lkyqKQ3KtVdCnmINL',
#     'is_local': False,
#     'name': 'Danger Zone - 2002 Remaster',
#     'popularity': 30,
#     'preview_url': 'https://p.scdn.co/mp3-preview/9a15593d5330c8bed7a959a7dfdfadfdf06cf1e6?cid=38c840c7b1394a1a864fbc6b40e96d0d',
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:4ftS7lkyqKQ3KtVdCnmINL'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6vjAwcOZNHp71G8mYs2yUg'},
#        'href': 'https://api.spotify.com/v1/artists/6vjAwcOZNHp71G8mYs2yUg',
#        'id': '6vjAwcOZNHp71G8mYs2yUg',
#        'name': 'DJ ZeeZee',
#        'type': 'artist',
#        'uri': 'spotify:artist:6vjAwcOZNHp71G8mYs2yUg'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2AFI0lCU0ILKZW9Plkno6n'},
#      'href': 'https://api.spotify.com/v1/albums/2AFI0lCU0ILKZW9Plkno6n',
#      'id': '2AFI0lCU0ILKZW9Plkno6n',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27386e6433451e00f3a009051c2',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0286e6433451e00f3a009051c2',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485186e6433451e00f3a009051c2',
#        'width': 64}],
#      'name': 'Danger Zone',
#      'release_date': '2019-04-11',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:2AFI0lCU0ILKZW9Plkno6n'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6vjAwcOZNHp71G8mYs2yUg'},
#       'href': 'https://api.spotify.com/v1/artists/6vjAwcOZNHp71G8mYs2yUg',
#       'id': '6vjAwcOZNHp71G8mYs2yUg',
#       'name': 'DJ ZeeZee',
#       'type': 'artist',
#       'uri': 'spotify:artist:6vjAwcOZNHp71G8mYs2yUg'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 172500,
#     'explicit': False,
#     'external_ids': {'isrc': 'SE5IB1900484'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/48gfj7REhcvZjASWAPEo68'},
#     'href': 'https://api.spotify.com/v1/tracks/48gfj7REhcvZjASWAPEo68',
#     'id': '48gfj7REhcvZjASWAPEo68',
#     'is_local': False,
#     'name': 'Danger Zone',
#     'popularity': 38,
#     'preview_url': 'https://p.scdn.co/mp3-preview/368e7c850ab6ddfb006f5ae757199c5ada1d109d?cid=38c840c7b1394a1a864fbc6b40e96d0d',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:48gfj7REhcvZjASWAPEo68'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1DLsogyGi0pwPtwV78D8uZ'},
#        'href': 'https://api.spotify.com/v1/artists/1DLsogyGi0pwPtwV78D8uZ',
#        'id': '1DLsogyGi0pwPtwV78D8uZ',
#        'name': 'KDrew',
#        'type': 'artist',
#        'uri': 'spotify:artist:1DLsogyGi0pwPtwV78D8uZ'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
# ...
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 196418,
#     'explicit': True,
#     'external_ids': {'isrc': 'QZES61801785'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2c1MoaYcylTXwG588SYh8j'},
#     'href': 'https://api.spotify.com/v1/tracks/2c1MoaYcylTXwG588SYh8j',
#     'id': '2c1MoaYcylTXwG588SYh8j',
#     'is_local': False,
#     'name': 'Danger Zone',
#     'popularity': 25,
#     'preview_url': 'https://p.scdn.co/mp3-preview/6d127da1d92515bb8db9674c2653fe89b662e5ab?cid=38c840c7b1394a1a864fbc6b40e96d0d',
#     'track_number': 9,
#     'type': 'track',
#     'uri': 'spotify:track:2c1MoaYcylTXwG588SYh8j'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0vDwx0CU6ln0giCDLK6k8D'},
#        'href': 'https://api.spotify.com/v1/artists/0vDwx0CU6ln0giCDLK6k8D',
#        'id': '0vDwx0CU6ln0giCDLK6k8D',
#        'name': 'Cherlene',
#        'type': 'artist',
#        'uri': 'spotify:artist:0vDwx0CU6ln0giCDLK6k8D'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4PIrTzsajipA45y7Uvg9X0'},
#      'href': 'https://api.spotify.com/v1/albums/4PIrTzsajipA45y7Uvg9X0',
#      'id': '4PIrTzsajipA45y7Uvg9X0',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2731d9a4d2294f9560c5a9b1878',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e021d9a4d2294f9560c5a9b1878',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048511d9a4d2294f9560c5a9b1878',
#        'width': 64}],
#      'name': 'Archer: Cherlene (Songs from the TV Series)',
#      'release_date': '2014-01-13',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:4PIrTzsajipA45y7Uvg9X0'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0vDwx0CU6ln0giCDLK6k8D'},
#       'href': 'https://api.spotify.com/v1/artists/0vDwx0CU6ln0giCDLK6k8D',
#       'id': '0vDwx0CU6ln0giCDLK6k8D',
#       'name': 'Cherlene',
#       'type': 'artist',
#       'uri': 'spotify:artist:0vDwx0CU6ln0giCDLK6k8D'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3Y3xIwWyq5wnNHPp5gPjOW'},
#       'href': 'https://api.spotify.com/v1/artists/3Y3xIwWyq5wnNHPp5gPjOW',
#       'id': '3Y3xIwWyq5wnNHPp5gPjOW',
#       'name': 'Kenny Loggins',
#       'type': 'artist',
#       'uri': 'spotify:artist:3Y3xIwWyq5wnNHPp5gPjOW'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 221189,
#     'explicit': False,
#     'external_ids': {'isrc': 'USFM91400002'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/50J6XwEbkYxNb5e4k6R9s1'},
#     'href': 'https://api.spotify.com/v1/tracks/50J6XwEbkYxNb5e4k6R9s1',
#     'id': '50J6XwEbkYxNb5e4k6R9s1',
#     'is_local': False,
#     'name': 'Danger Zone',
#     'popularity': 29,
#     'preview_url': None,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:50J6XwEbkYxNb5e4k6R9s1'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/75qfbB5WRdhNF7WLZU52xW'},
#      'href': 'https://api.spotify.com/v1/albums/75qfbB5WRdhNF7WLZU52xW',
#      'id': '75qfbB5WRdhNF7WLZU52xW',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2730c6ec503bd5bbc6608167941',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e020c6ec503bd5bbc6608167941',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048510c6ec503bd5bbc6608167941',
#        'width': 64}],
#      'name': 'Danger Zone',
#      'release_date': '2007-06-26',
#      'release_date_precision': 'day',
#      'total_tracks': 16,
#      'type': 'album',
#      'uri': 'spotify:album:75qfbB5WRdhNF7WLZU52xW'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1DisOtNFBsfGAuifnt4o8j'},
#       'href': 'https://api.spotify.com/v1/artists/1DisOtNFBsfGAuifnt4o8j',
#       'id': '1DisOtNFBsfGAuifnt4o8j',
#       'name': 'Chino Grande',
#       'type': 'artist',
#       'uri': 'spotify:artist:1DisOtNFBsfGAuifnt4o8j'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4a8TMzvDnszW2iJbqjXvcr'},
#       'href': 'https://api.spotify.com/v1/artists/4a8TMzvDnszW2iJbqjXvcr',
#       'id': '4a8TMzvDnszW2iJbqjXvcr',
#       'name': 'Travie',
#       'type': 'artist',
#       'uri': 'spotify:artist:4a8TMzvDnszW2iJbqjXvcr'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4Byc3x9CcT699ZmORPccck'},
#       'href': 'https://api.spotify.com/v1/artists/4Byc3x9CcT699ZmORPccck',
#       'id': '4Byc3x9CcT699ZmORPccck',
#       'name': 'Midget Loco',
#       'type': 'artist',
#       'uri': 'spotify:artist:4Byc3x9CcT699ZmORPccck'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4wMWhQQx82agVd7osP1hRT'},
#       'href': 'https://api.spotify.com/v1/artists/4wMWhQQx82agVd7osP1hRT',
#       'id': '4wMWhQQx82agVd7osP1hRT',
#       'name': 'Trouble of Brown Side',
#       'type': 'artist',
#       'uri': 'spotify:artist:4wMWhQQx82agVd7osP1hRT'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/7sgVAztHMVXGT4XiczZb6F'},
#       'href': 'https://api.spotify.com/v1/artists/7sgVAztHMVXGT4XiczZb6F',
#       'id': '7sgVAztHMVXGT4XiczZb6F',
#       'name': 'Baby Jokes',
#       'type': 'artist',
#       'uri': 'spotify:artist:7sgVAztHMVXGT4XiczZb6F'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/2MSULrgm9zdQfT93lgw4cE'},
#       'href': 'https://api.spotify.com/v1/artists/2MSULrgm9zdQfT93lgw4cE',
#       'id': '2MSULrgm9zdQfT93lgw4cE',
#       'name': 'Lil Tripper',
#       'type': 'artist',
#       'uri': 'spotify:artist:2MSULrgm9zdQfT93lgw4cE'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 290546,
#     'explicit': True,
#     'external_ids': {'isrc': 'USPRZ0810308'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4EeCMt2dbO1GOU19sEAJsf'},
#     'href': 'https://api.spotify.com/v1/tracks/4EeCMt2dbO1GOU19sEAJsf',
#     'id': '4EeCMt2dbO1GOU19sEAJsf',
#     'is_local': False,
#     'name': 'Danger Zone',
#     'popularity': 21,
#     'preview_url': 'https://p.scdn.co/mp3-preview/de28f48e491c98bea3b99c7d11fc2a09abc15107?cid=38c840c7b1394a1a864fbc6b40e96d0d',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:4EeCMt2dbO1GOU19sEAJsf'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6AEIKVwB27miPI3uJxM4Dw'},
#        'href': 'https://api.spotify.com/v1/artists/6AEIKVwB27miPI3uJxM4Dw',
#        'id': '6AEIKVwB27miPI3uJxM4Dw',
#        'name': "Pickin' On Series",
#        'type': 'artist',
#        'uri': 'spotify:artist:6AEIKVwB27miPI3uJxM4Dw'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5v11gs2O8Qu8HZcrJTnWQw'},
#      'href': 'https://api.spotify.com/v1/albums/5v11gs2O8Qu8HZcrJTnWQw',
#      'id': '5v11gs2O8Qu8HZcrJTnWQw',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2731fee48a28ec11f4e3ba717aa',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e021fee48a28ec11f4e3ba717aa',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048511fee48a28ec11f4e3ba717aa',
#        'width': 64}],
#      'name': "Pickin' On the Biggest Hits of the 1980s Vol. 2",
#      'release_date': '2017-02-24',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:5v11gs2O8Qu8HZcrJTnWQw'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6AEIKVwB27miPI3uJxM4Dw'},
#       'href': 'https://api.spotify.com/v1/artists/6AEIKVwB27miPI3uJxM4Dw',
#       'id': '6AEIKVwB27miPI3uJxM4Dw',
#       'name': "Pickin' On Series",
#       'type': 'artist',
#       'uri': 'spotify:artist:6AEIKVwB27miPI3uJxM4Dw'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/28yx4Aq8882xd1AivwMZLB'},
#       'href': 'https://api.spotify.com/v1/artists/28yx4Aq8882xd1AivwMZLB',
#       'id': '28yx4Aq8882xd1AivwMZLB',
#       'name': 'Brad Davis',
#       'type': 'artist',
#       'uri': 'spotify:artist:28yx4Aq8882xd1AivwMZLB'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 216053,
#     'explicit': False,
#     'external_ids': {'isrc': 'USEWC1690143'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3JzOVXsaT5tTSxy28Tehpn'},
#     'href': 'https://api.spotify.com/v1/tracks/3JzOVXsaT5tTSxy28Tehpn',
#     'id': '3JzOVXsaT5tTSxy28Tehpn',
#     'is_local': False,
#     'name': 'Danger Zone',
#     'popularity': 21,
#     'preview_url': 'https://p.scdn.co/mp3-preview/87fc3dbb3710b27eed8a83e6e2dc25f4bc24d007?cid=38c840c7b1394a1a864fbc6b40e96d0d',
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:3JzOVXsaT5tTSxy28Tehpn'}],
#   'limit': 20,
#   'next': 'https://api.spotify.com/v1/search?query=Danger+Zone&type=track&offset=20&limit=20',
#   'offset': 0,
#   'previous': None,
#   'total': 3076}}
